# %%
#SimpleImputer - to handle missing values.It is a sklearn machine learning library that provide support for handling missing data.
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv(r'C:\Users\user2222\Downloads\covid_19_data\covid_19_datalatest.csv')# r is for encoding.

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1       1/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2       1/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3       1/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4       1/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5       1/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# 4          0       0          0

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1       1/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2       1/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3       1/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4       1/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5       1/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6       1/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7       1/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8       1/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9       1/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10       1/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# ...

# %%
df.drop(['SNo', 'Last Update'], axis=1,inplace=True)#inplace-do that changing in df variable itself

# %%
df.head()
# Out:
#   ObservationDate Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0       1/22/2020          Anhui  Mainland China          1       0          0
# 1       1/22/2020        Beijing  Mainland China         14       0          0
# 2       1/22/2020      Chongqing  Mainland China          6       0          0
# 3       1/22/2020         Fujian  Mainland China          1       0          0
# 4       1/22/2020          Gansu  Mainland China          0       0          0

# %%
   df.rename(columns={'ObservationDate':'Date', 'Province/State':'Province', 'Country/Region':'Country'}, inplace=True)

# %%
df.head()
# Out:
#         Date   Province         Country  Confirmed  Deaths  Recovered
# 0  1/22/2020      Anhui  Mainland China          1       0          0
# 1  1/22/2020    Beijing  Mainland China         14       0          0
# 2  1/22/2020  Chongqing  Mainland China          6       0          0
# 3  1/22/2020     Fujian  Mainland China          1       0          0
# 4  1/22/2020      Gansu  Mainland China          0       0          0

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date   Province         Country  Confirmed  Deaths  Recovered
# 0 2020-01-22      Anhui  Mainland China          1       0          0
# 1 2020-01-22    Beijing  Mainland China         14       0          0
# 2 2020-01-22  Chongqing  Mainland China          6       0          0
# 3 2020-01-22     Fujian  Mainland China          1       0          0
# 4 2020-01-22      Gansu  Mainland China          0       0          0

# %%
df.describe() #brings the statistics of the data
# Out:
#           Confirmed         Deaths     Recovered
# count  2.059510e+05  205951.000000  2.059510e+05
# mean   4.540148e+04    1262.633850  2.766348e+04
# std    1.437216e+05    4082.838603  1.334517e+05
# min   -3.028440e+05    -178.000000 -8.544050e+05
# 25%    5.960000e+02       7.000000  1.100000e+01
# 50%    5.361000e+03     101.000000  1.028000e+03
# 75%    2.618400e+04     713.000000  9.880000e+03
# max    3.049037e+06   80143.000000  6.399531e+06

# %%
df.info()#  gives more information about the null. Missing values are data that are not available in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205951 entries, 0 to 205950
# Data columns (total 6 columns):
# Date         205951 non-null datetime64[ns]
# Province     150574 non-null object
# Country      205951 non-null object
# Confirmed    205951 non-null int64
# Deaths       205951 non-null int64
# Recovered    205951 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 9.4+ MB

# %%
df.fillna('NA')
# Out:
#              Date           Province         Country  Confirmed  Deaths  \
# 0      2020-01-22              Anhui  Mainland China          1       0
# 1      2020-01-22            Beijing  Mainland China         14       0
# 2      2020-01-22          Chongqing  Mainland China          6       0
# 3      2020-01-22             Fujian  Mainland China          1       0
# 4      2020-01-22              Gansu  Mainland China          0       0
# ...           ...                ...             ...        ...     ...
# 205946 2021-01-19  Zaporizhia Oblast         Ukraine      62492     738
# 205947 2021-01-19            Zeeland     Netherlands      13031     149
# 205948 2021-01-19           Zhejiang  Mainland China       1316       1
# 205949 2021-01-19    Zhytomyr Oblast         Ukraine      42758     707
# 205950 2021-01-19       Zuid-Holland     Netherlands     224398    3153
#
#         Recovered
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
df
# Out:
#              Date           Province         Country  Confirmed  Deaths  \
# 0      2020-01-22              Anhui  Mainland China          1       0
# 1      2020-01-22            Beijing  Mainland China         14       0
# 2      2020-01-22          Chongqing  Mainland China          6       0
# 3      2020-01-22             Fujian  Mainland China          1       0
# 4      2020-01-22              Gansu  Mainland China          0       0
# ...           ...                ...             ...        ...     ...
# 205946 2021-01-19  Zaporizhia Oblast         Ukraine      62492     738
# 205947 2021-01-19            Zeeland     Netherlands      13031     149
# 205948 2021-01-19           Zhejiang  Mainland China       1316       1
# 205949 2021-01-19    Zhytomyr Oblast         Ukraine      42758     707
# 205950 2021-01-19       Zuid-Holland     Netherlands     224398    3153
#
#         Recovered
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
#SimpleImputer

# %%
#imputer = SimpleImputer(strategy='constant')
#df2 = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
#Group by country
df2 = df.groupby('Country')[['Country', 'Confirmed', 'Deaths','Recovered']].sum().reset_index()
#Group the country together and join all the record of each country ,sum all of them.
df2
# Out:
#                             Country  Confirmed  Deaths  Recovered
# 0                        Azerbaijan          1       0          0
# 1                   ('St. Martin',)          2       0          0
# 2                       Afghanistan    9497206  340564    6834349
# 3                           Albania    4933931  111888    2714547
# 4                           Algeria   12523828  431100    8457420
# ..                              ...        ...     ...        ...
# 221              West Bank and Gaza   11547318  105200    9235431
# 222                           Yemen     422323  120553     247348
# 223                          Zambia    2977675   61978    2642823
# 224                        Zimbabwe    1743181   46910    1313022
# 225  occupied Palestinian territory         25       0          0
#
# [226 rows x 4 columns]

# %%
#df2 contain the data respect to each country. For each country, sort by date and country.For each country for all the date.
df2 = df.groupby(['Country', 'Date'])[['Country','Date','Confirmed','Deaths', 'Recovered']].sum().reset_index()
df2
# Out:
#                               Country       Date  Confirmed  Deaths  Recovered
# 0                          Azerbaijan 2020-02-28          1       0          0
# 1                     ('St. Martin',) 2020-03-10          2       0          0
# 2                         Afghanistan 2020-02-24          1       0          0
# 3                         Afghanistan 2020-02-25          1       0          0
# 4                         Afghanistan 2020-02-26          1       0          0
# ...                               ...        ...        ...     ...        ...
# 61515  occupied Palestinian territory 2020-03-12          0       0          0
# 61516  occupied Palestinian territory 2020-03-14          0       0          0
# 61517  occupied Palestinian territory 2020-03-15          0       0          0
# 61518  occupied Palestinian territory 2020-03-16          0       0          0
# 61519  occupied Palestinian territory 2020-03-17          0       0          0
#
# ...

# %%
df3 = df2[df2 ['Confirmed']>100]

# %%
df3# All the records that the confirmed cases are more than 100
# Out:
#            Country       Date  Confirmed  Deaths  Recovered
# 35     Afghanistan 2020-03-28        107       4          2
# 36     Afghanistan 2020-03-29        118       4          2
# 37     Afghanistan 2020-03-30        146       4          2
# 38     Afghanistan 2020-03-31        175       4          5
# 39     Afghanistan 2020-04-01        197       4          5
# ...            ...        ...        ...     ...        ...
# 61508     Zimbabwe 2021-01-15      26109     666      15414
# 61509     Zimbabwe 2021-01-16      26881     683      15872
# 61510     Zimbabwe 2021-01-17      27203     713      16512
# 61511     Zimbabwe 2021-01-18      27892     773      17372
# 61512     Zimbabwe 2021-01-19      28675     825      18110
#
# [51222 rows x 5 columns]

# %%
#Matplotlib for plot graph, 2d plot and lot more.
#Visualization Matplotlib gives a very good insight of the data.
#Most popular module in Matplotlib is pyplot
#import matplotlib.pyplot as plt or
#from matplotlib import pyplot as plt

# %%
#Create 1,000 point in between 0 and 10
#sin function is element on this numpy array, which will actually plot(x,y). 
#y = sin(x)

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x));

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x,y)

# %%
#plt.scatter(x,y) helps to plot in point(0) form rather than in line form.
plt.scatter(x,y)

# %%
plt.scatter(x[:30], y[:30]) #gives the first 30 values

# %%
 plt.scatter(x[::10],y[::10])#From every begining, go to end, pick every 10th point. do the same with Y.

# %%
plt.scatter(x[::10], y[::10], color ='red')

# %%
plt.plot(x,y,color='b')
plt.plot(x,np.cos(x), color ='g')

# %%
#sklearn for machine learning, pytorch for deep learning, Tensorflow for prediction, classification, regression and lots more.
plt.plot(x,x+0,'-g')#solid green
plt.plot(x,x+1,'--c')#dashed cyan
plt.plot(x,x+2,'-k')#dashdot black
plt.plot(x,x+3,':r')#dotted red

# %%
#To get all the countries without repetition
countries = df3['Country'].unique()
len(countries)
# Out:
# 183

# %%
#How many unique counting are there, in the data file.
#For each country, we want to check what is the trend of recovered patient, Confirmed Patients, deaths patients as the date move on.

# %%
#Legend enable the label command in the plt.scatter to appear in the figure.

# %%
plt.show() #To show each Iteration.
